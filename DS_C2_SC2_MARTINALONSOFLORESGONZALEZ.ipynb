# %%
import pandas as pd
import numpy as np

# %% [markdown]
# a. Extraer la información del archivo.

# %%
df = pd.read_csv("country_vaccinations.csv")
df.head(5)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %% [markdown]
#  b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
df["date"] = df["date"].astype("datetime64")
df.dtypes
# Out:
# country                                        object
# iso_code                                       object
# date                                   datetime64[ns]
# total_vaccinations                            float64
# people_vaccinated                             float64
# people_fully_vaccinated                       float64
# daily_vaccinations_raw                        float64
# daily_vaccinations                            float64
# total_vaccinations_per_hundred                float64
# people_vaccinated_per_hundred                 float64
# people_fully_vaccinated_per_hundred           float64
# daily_vaccinations_per_million                float64
# vaccines                                       object
# source_name                                    object
# source_website                                 object
# dtype: object

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines).

# %%
dfg= df[["daily_vaccinations", "vaccines"]].groupby("vaccines").sum()
dfg # esta es una tabla que muestra el total de vacunas aplicadas por compañias
# Out:
#                                                     daily_vaccinations
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pf...           9616160.0
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bio...         201816053.0
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02,...          37861146.0
# Abdala, Soberana Plus, Soberana02                           33802957.0
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/Ast...         146357015.0
# ...                                                                ...
# Pfizer/BioNTech, Sinovac, Turkovac                         147484328.0
# Pfizer/BioNTech, Sputnik V                                     68643.0
# QazVac, Sinopharm/Beijing, Sputnik V                        20891256.0
# Sinopharm/Beijing                                             893824.0
# Sinopharm/Beijing, Sputnik V                                14398697.0
#
# [84 rows x 1 columns]

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
df["daily_vaccinations"].sum()
# Out:
# 11320239871.0

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
df[["country", "daily_vaccinations"]].groupby("country").mean() # promedio de vacunas aplicadas por dia en cada pais
# Out:
#                    daily_vaccinations
# country
# Afghanistan              14610.681934
# Albania                   6276.210046
# Algeria                  33904.356436
# Andorra                    367.716019
# Angola                   44821.457584
# ...                               ...
# Wales                    15518.411765
# Wallis and Futuna           33.886486
# Yemen                     2556.115756
# Zambia                    9649.805158
# Zimbabwe                 21669.066832
#
# [223 rows x 1 columns]

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo.

# %%
df[df["date"] == "2021-01-29"]["daily_vaccinations"].sum()
# Out:
# 4884052.0

# %% [markdown]
# g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.

# %%
conDiferencias = df.copy()
conDiferencias["diferencias"] =   conDiferencias["daily_vaccinations"] - conDiferencias["daily_vaccinations_raw"].fillna(0)
conDiferencias.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website  diferencias
# 0  World Health Organization  https://covid19.who.int/          NaN
# 1  World Health Organization  https://covid19.who.int/       1367.0
# 2  World Health Organization  https://covid19.who.int/       1367.0
# 3  World Health Organization  https://covid19.who.int/       1367.0
# 4  World Health Organization  https://covid19.who.int/       1367.0

# %% [markdown]
# h. Obtener el período de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
df["date"].max() - df["date"].min()
# Out:
# Timedelta('482 days 00:00:00')

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter /).

# %%
conCantidad = df.copy()

def cantidad_empresa(fila):
  if fila["daily_vaccinations"] > 0:
    cantidad = fila["daily_vaccinations"]
  else:
    cantidad = 0
  return  str(cantidad) + "/" + fila['vaccines']

conCantidad['canVac'] = conCantidad .apply(lambda row: cantidad_empresa(row), axis=1)
conCantidad.head(10)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG 2021-02-27                 NaN                NaN
# 6  Afghanistan      AFG 2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG 2021-03-01                 NaN                NaN
# 8  Afghanistan      AFG 2021-03-02                 NaN                NaN
# 9  Afghanistan      AFG 2021-03-03                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
# 5                      NaN                     NaN              1367.0
# 6                      NaN                     NaN              1367.0
# 7                      NaN                     NaN              1580.0
# 8                      NaN                     NaN              1794.0
# 9                      NaN                     NaN              2008.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                            0.02                           0.02
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
# 5                                  NaN                            34.0
# 6                                  NaN                            34.0
# 7                                  NaN                            40.0
# 8                                  NaN                            45.0
# 9                                  NaN                            50.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 5  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 6  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 7  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 8  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 9  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website  \
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/
# 5  World Health Organization  https://covid19.who.int/
# 6  World Health Organization  https://covid19.who.int/
# 7  World Health Organization  https://covid19.who.int/
# 8  World Health Organization  https://covid19.who.int/
# 9  World Health Organization  https://covid19.who.int/
#
#                                               canVac
# 0  0/Johnson&Johnson, Oxford/AstraZeneca, Pfizer/...
# 1  1367.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...
# 2  1367.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...
# 3  1367.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...
# 4  1367.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...
# 5  1367.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...
# 6  1367.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...
# 7  1580.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...
# 8  1794.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...
# 9  2008.0/Johnson&Johnson, Oxford/AstraZeneca, Pf...

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20 = df[df["date"] < "2020-12-20"]
antes20.head(10)
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 13403  Canada      CAN 2020-12-14                 5.0                5.0
# 13404  Canada      CAN 2020-12-15               727.0              727.0
# 13405  Canada      CAN 2020-12-16              3025.0             3025.0
# 13406  Canada      CAN 2020-12-17              7279.0             7279.0
# 13407  Canada      CAN 2020-12-18             11296.0            11296.0
# 13408  Canada      CAN 2020-12-19             12367.0            12367.0
# 15756   China      CHN 2020-12-15           1500000.0                NaN
# 15757   China      CHN 2020-12-16                 NaN                NaN
# 15758   China      CHN 2020-12-17                 NaN                NaN
# 15759   China      CHN 2020-12-18                 NaN                NaN
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13403                      NaN                     NaN                 NaN
# 13404                      NaN                   722.0               722.0
# 13405                      NaN                  2298.0              1510.0
# 13406                      NaN                  4254.0              2425.0
# 13407                      NaN                  4017.0              2823.0
# 13408                      NaN                  1071.0              2472.0
# 15756                      NaN                     NaN                 NaN
# 15757                      NaN                     NaN            187500.0
# 15758                      NaN                     NaN            187500.0
# 15759                      NaN                     NaN            187500.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 13403                            0.00                           0.00
# 13404                            0.00                           0.00
# 13405                            0.01                           0.01
# 13406                            0.02                           0.02
# 13407                            0.03                           0.03
# 13408                            0.03                           0.03
# 15756                            0.10                            NaN
# 15757                             NaN                            NaN
# 15758                             NaN                            NaN
# 15759                             NaN                            NaN
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 13403                                  NaN                             NaN
# 13404                                  NaN                            19.0
# 13405                                  NaN                            40.0
# 13406                                  NaN                            64.0
# 13407                                  NaN                            74.0
# 13408                                  NaN                            65.0
# 15756                                  NaN                             NaN
# 15757                                  NaN                           130.0
# 15758                                  NaN                           130.0
# 15759                                  NaN                           130.0
#
#                                                 vaccines  \
# 13403  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13404  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13405  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13406  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13407  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13408  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 15756  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 15757  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 15758  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 15759  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
#
#                                              source_name  \
# 13403  Official data from provinces via covid19tracke...
# 13404  Official data from provinces via covid19tracke...
# 13405  Official data from provinces via covid19tracke...
# 13406  Official data from provinces via covid19tracke...
# 13407  Official data from provinces via covid19tracke...
# 13408  Official data from provinces via covid19tracke...
# 15756                         National Health Commission
# 15757                         National Health Commission
# 15758                         National Health Commission
# 15759                         National Health Commission
#
#                                           source_website
# 13403  https://covid19tracker.ca/vaccinationtracker.html
# 13404  https://covid19tracker.ca/vaccinationtracker.html
# 13405  https://covid19tracker.ca/vaccinationtracker.html
# 13406  https://covid19tracker.ca/vaccinationtracker.html
# 13407  https://covid19tracker.ca/vaccinationtracker.html
# 13408  https://covid19tracker.ca/vaccinationtracker.html
# 15756  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...
# 15757  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...
# 15758  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...
# 15759  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
pfizer = df[df['vaccines'].str.contains(pat = 'Pfizer')]
pfizer.head(10)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG 2021-02-27                 NaN                NaN
# 6  Afghanistan      AFG 2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG 2021-03-01                 NaN                NaN
# 8  Afghanistan      AFG 2021-03-02                 NaN                NaN
# 9  Afghanistan      AFG 2021-03-03                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
# 5                      NaN                     NaN              1367.0
# 6                      NaN                     NaN              1367.0
# 7                      NaN                     NaN              1580.0
# 8                      NaN                     NaN              1794.0
# 9                      NaN                     NaN              2008.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                            0.02                           0.02
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
# 5                                  NaN                            34.0
# 6                                  NaN                            34.0
# 7                                  NaN                            40.0
# 8                                  NaN                            45.0
# 9                                  NaN                            50.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 5  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 6  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 7  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 8  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 9  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/
# 5  World Health Organization  https://covid19.who.int/
# 6  World Health Organization  https://covid19.who.int/
# 7  World Health Organization  https://covid19.who.int/
# 8  World Health Organization  https://covid19.who.int/
# 9  World Health Organization  https://covid19.who.int/

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter.

# %%
writer = pd.ExcelWriter('resultadosReto.xlsx')
conDiferencias.to_excel(writer, sheet_name="conDiferencias")  
conCantidad.to_excel(writer, sheet_name="conCantidad")
antes20.to_excel(writer, sheet_name="antes20")
pfizer.to_excel(writer, sheet_name="pfizer")
writer.save()
writer.close()
